# %% [markdown]
# <a href="https://colab.research.google.com/github/niranjanbsubramanian/matplotlib-visualization/blob/main/plotting_with_matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Line Plot

# %%
import pandas as pd
import matplotlib.pyplot as plt

#number of ice creams sold for the week
ice_cream = [35,33,65,44,75,88,101]

plt.plot(ice_cream)

plt.show()

# %% [markdown]
# ### Scatter Plot

# %% [markdown]
# Download the [dataset here.](https://www.kaggle.com/rohankayan/years-of-experience-and-salary-dataset?select=Salary_Data.csv)

# %%
sal = pd.read_csv('/Salary_Data.csv')
sal.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
experience = sal['YearsExperience']
salary = sal['Salary']

plt.scatter(experience, salary)
plt.show()

# %% [markdown]
# ### Bar Plot

# %%
ice_cream = [35,33,65,44,75,88,101]
days = ['Mon','Tues','Wed','Thur','Fri','Sat','Sun']

plt.bar(days, ice_cream)
plt.show()

# %%
ice_cream = [35,33,65,44,75,88,101]
days = ['Mon','Tues','Wed','Thur','Fri','Sat','Sun']

plt.barh(days, ice_cream)
plt.show()

# %% [markdown]
# ### Pie Chart

# %%
# https://gs.statcounter.com/browser-market-share
x = [64.73,18.43,3.37,3.36,10.11]
labels = ['Chrome', 'Safari', 'Edge', 'Firefox', 'Others']

plt.pie(x, labels=labels,autopct='%.1f%%')
plt.show()

# %%
x = [64.73,18.43,3.37,3.36,10.11]
labels = ['Chrome', 'Safari', 'Edge', 'Firefox', 'Others']

plt.pie(x, labels=labels,autopct='%.1f%%',explode=[0.1]*5)
plt.show()

# %%
x = [64.73,18.43,3.37,3.36,10.11]
labels = ['Chrome', 'Safari', 'Edge', 'Firefox', 'Others']

plt.pie(x, labels=labels,autopct='%.1f%%',explode=[0,0.3,0,0,0])
plt.show()

# %% [markdown]
# ### Histogram

# %%
plt.hist(salary, bins=7)
plt.show()

# %%
plt.hist(salary, bins=8)
plt.show()

# %% [markdown]
# #### BOX PLOT

# %%
import pandas as pd
import matplotlib.pyplot as plt

sal = pd.read_csv('/content/Salary_Data.csv')

experience = sal['YearsExperience']
salary = sal['Salary']

plt.boxplot(salary)
plt.show()

# %% [markdown]
# ### Making plots readable

# %% [markdown]
# #### Adding Title

# %%
import pandas as pd
import matplotlib.pyplot as plt

#number of ice creams sold for the week
ice_cream = [35,33,65,44,75,88,101]

plt.plot(ice_cream)
plt.title('Ice cream sales')
plt.show()

# %% [markdown]
# #### Adding x and y label

# %%
import pandas as pd
import matplotlib.pyplot as plt

#number of ice creams sold for the week
ice_cream = [35,33,65,44,75,88,101]

plt.plot(ice_cream)
plt.title('Ice Cream Sales')
plt.xlabel('Day')
plt.ylabel('# ice creams sold')
plt.show()

# %% [markdown]
# #### Adding Legend

# %%
plt.plot(ice_cream, label='No. Of Ice Creams sold')
plt.title('Ice Cream Sales')
plt.xlabel('Day')
plt.ylabel('# ice creams sold')
plt.legend()
plt.show()

# %%
plt.plot(ice_cream, label='No. Of Ice Creams sold')
plt.title('Ice Cream Sales')
plt.xlabel('Day')
plt.ylabel('# ice creams sold')
plt.legend(loc='lower right')
plt.show()

# %%
days = ['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday']
plt.plot(days, ice_cream, label='No. Of Ice Creams sold')
plt.title('Ice Cream Sales')
plt.xlabel('Day')
plt.ylabel('# ice creams sold')
plt.legend(loc='lower right')
plt.show()

# %%
days = ['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday']
plt.plot(days, ice_cream, label='No. Of Ice Creams sold')
plt.title('Ice Cream Sales')
plt.xlabel('Day')
plt.ylabel('# ice creams sold')
plt.legend(loc='lower right')
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# ### Advanced Subplots

# %% [markdown]
# #### Subplot function

# %% [markdown]
# Download the [dataset here.](https://www.kaggle.com/uciml/iris)

# %%
import pandas as pd
import matplotlib.pyplot as plt

iris = pd.read_csv('/content/Iris.csv')

plt.subplot(2,2,1)
plt.title('Sepal Length')
plt.hist(iris['SepalLengthCm'])

plt.subplot(2,2,2)
plt.title('Sepal Width')
plt.hist(iris['SepalWidthCm'])

plt.subplot(2,2,3)
plt.title('Petal Length')
plt.hist(iris['PetalLengthCm'])

plt.subplot(2,2,4)
plt.title('Petal Width')
plt.hist(iris['PetalWidthCm'])

plt.show()

plt.savefig('output')

# %% [markdown]
# #### tight_layout

# %%
import pandas as pd
import matplotlib.pyplot as plt

iris = pd.read_csv('/content/Iris.csv')

plt.subplot(2,2,1)
plt.title('Sepal Length')
plt.hist(iris['SepalLengthCm'])

plt.subplot(2,2,2)
plt.title('Sepal Width')
plt.hist(iris['SepalWidthCm'])

plt.subplot(2,2,3)
plt.title('Petal Length')
plt.hist(iris['PetalLengthCm'])

plt.subplot(2,2,4)
plt.title('Petal Width')
plt.hist(iris['PetalWidthCm'])

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Saving a Figure

# %%
import pandas as pd
import matplotlib.pyplot as plt

#number of ice creams sold for the week
ice_cream = [35,33,65,44,75,88,101]

plt.plot(ice_cream)

plt.show()

plt.savefig('output.png')
